# %%
import pandas as pd
w = pd.read_csv('./worldwide internet prices in 2022 - IN 2022 (1).csv')
w.head(60)
#w.loc[0,'Continental region']
# Out:
#    Country code                Name    Continental region  \
# 0            IL              Israel             NEAR EAST
# 1            KG          Kyrgyzstan     CIS (FORMER USSR)
# 2            FJ                Fiji               OCEANIA
# 3            IT               Italy        WESTERN EUROPE
# 4            SD               Sudan    SUB-SAHARAN AFRICA
# 5            RU  Russian Federation     CIS (FORMER USSR)
# 6            MD             Moldova        EASTERN EUROPE
# 7            BD          Bangladesh  ASIA (EX. NEAR EAST)
# 8            LK           Sri Lanka  ASIA (EX. NEAR EAST)
# 9            CL               Chile         SOUTH AMERICA
# 10           FR              France        WESTERN EUROPE
# 11           ID           Indonesia  ASIA (EX. NEAR EAST)
# 12           BY             Belarus     CIS (FORMER USSR)
# 13           SM          San Marino        WESTERN EUROPE
# 14           VN             Vietnam  ASIA (EX. NEAR EAST)
# ...

# %%
q = len(w)
e = ()
for i in range(q):
    for r in range(4,9):
        x = w.iloc[i,r]
        if x != 'Nan':
            print(x[1:])
# Out:
# 0.05
# 0.02
# 20.95
# 0.11
# 0.90
# 0.15
# 0.10
# 7.08
# 0.21
# 0.27
# 0.19
# 0.05
# 0.85
# 0.59
# 3.57
# 0.27
# 0.09
# 3.54
# 0.43
# 1.73
# 0.27
# 0.03
# 0.92
# 0.63
# 0.68
# 0.29
# 0.13
# 1.86
# 0.52
# 0.91
# 0.32
# 0.07
# 2.79
# 1.12
# 2.82
# 0.34
# 0.11
# 2.22
# 0.70
# 0.99
# 0.38
# 0.00
# 5.53
# 0.51
# 0.78
# 0.39
# 0.24
# 1.83
# 0.71
# 1.87
# 0.41
# 0.09
# 118.20
# 0.81
# 1.21
# 0.42
# 0.17
# 2.94
# 0.64
# 2.99
# 0.43
# 0.02
# 16.62
# 0.89
# 2.36
# 0.43
# 0.24
# 0.63
# 1.16
# 6.86
# 0.49
# 0.07
# 5.55
# 0.57
# 1.31
# 0.51
# 0.16
# 2.24
# 0.65
# 5.15
# 0.52
# 0.30
# 1.21
# 0.61
# 9.89
# 0.56
# 0.19
# 6.86
# 10.86
# 30.09
# 0.59
# 0.06
# 8.59
# 0.69
# 1.85
# 0.59
# 0.25
# 2.35
# 0.46
# 0.49
# 0.60
# 0.01
# 23.75
# 1.34
# 3.27
# 0.60
# 0.18
# 6.67
# 0.50
# 6.19
# 0.60
# 0.22
# 3.70
# 0.74
# 0.82
# 0.61
# 0.22
# 2.66
# 0.86
# 2.25
# 0.63
# 0.05
# 2.26
# 0.72
# 2.25
# 0.64
# 0.03
# 23.02
# 0.70
# 1.32
# 0.66
# 0.17
# 3.47
# 0.94
# 1.56
# 0.68
# 0.05
# 2.73
# 0.09
# 0.26
# 0.70
# ...

# %%
import matplotlib.pyplot as plt
w = pd.read_csv('./worldwide internet prices in 2022 - IN 2022 (1).csv')
x = w.loc[0:,'Cheapest 1GB for 30 days (USD)']
y = w.loc[0:,'Most expensive 1GB (USD)']
plt.scatter(x,y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 5
#       3 x = w.loc[0:,'Cheapest 1GB for 30 days (USD)']
#       4 y = w.loc[0:,'Most expensive 1GB (USD)']
# ----> 5 plt.scatter(x,y)
#       6 plt.show()
#
# File c:\Users\kege\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\pyplot.py:3684, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    <a href='file:///c%3A/Users/kege/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/pyplot.py?line=3664'>3665</a> @_copy_docstring_and_deprecators(Axes.scatter)
#    <a href='file:///c%3A/Users/kege/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/pyplot.py?line=3665'>3666</a> def scatter(
# ...
