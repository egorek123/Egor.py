# %%
import pandas as pd
f = pd.read_csv('worldwide internet prices in 2022 - IN 2022 (1).csv')
f.dropna()
# Out:
#     Country code                   Name  Continental region  \
# 0             IL                 Israel           NEAR EAST
# 1             KG             Kyrgyzstan   CIS (FORMER USSR)
# 2             FJ                   Fiji             OCEANIA
# 3             IT                  Italy      WESTERN EUROPE
# 4             SD                  Sudan  SUB-SAHARAN AFRICA
# ..           ...                    ...                 ...
# 225           MW                 Malawi  SUB-SAHARAN AFRICA
# 226           ST  São Tomé and Príncipe  SUB-SAHARAN AFRICA
# 227           SH           Saint Helena  SUB-SAHARAN AFRICA
# 228           FK       Falkland Islands       SOUTH AMERICA
# 229           GQ      Equatorial Guinea  SUB-SAHARAN AFRICA
#
#      NO. OF Internet Plans  Average price of 1GB (USD)  \
# 0                      27.0                      $0.05
# 1                      20.0                      $0.15
# 2                      18.0                      $0.19
# ...

# %%
import pandas as pd

dist = {'A':['1','2','3'],'B':['4','5','6'],'C':[7,8,9]}
pd_dist = pd.DataFrame(dist)
pd_dist['A']  = pd.to_numeric(pd_dist['A'])
pd_dist['B']  = pd.to_numeric(pd_dist['B'])
#pd_dist.describe()
print(pd_dist.dtypes)
# Out:
# A    int64
# B    int64
# C    int64
# dtype: object

# %%
import pandas as pd
df = pd.DataFrame({'date_1':['2022-01-01','2022-01-02','2022-01-03',],
                   'time_1':['10:00:00','11:00:00','12:00:00',],
                   'date_2':['01/01/2022','01/02/2022','01/03/2022',],
                   'time_2':['10:00 AM','11:00 AM','12:00 PM',]})
df.to_csv('dad.csv',index=False)
